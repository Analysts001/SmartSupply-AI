# %%
# !pip install google-cloud-bigquery pandas --quiet

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client()

# %%
from google.colab import auth
auth.authenticate_user()

from google.cloud import bigquery
import pandas as pd


client = bigquery.Client(project="smartsupply-ai")

# %%
from google.cloud import bigquery

project_id = "smartsupply-ai"
client = bigquery.Client(project=project_id)

# %%
query = """
SELECT *
FROM `smartsupply-ai.smartsupply.shipments`
"""

df = client.query(query).to_dataframe()

df.head()
# Out:
#      ID Project Code            PQ # PO _ SO # ASN_DN #        Country  \
# 0  7983   113-ZW-T01  Pre-PQ Process  SCMS-231  ASN-139       Zimbabwe
# 1    68   113-ZW-T01  Pre-PQ Process  SCMS-308  ASN-285       Zimbabwe
# 2  6671   104-CI-T01  Pre-PQ Process  SCMS-609  ASN-704  Côte d'Ivoire
# 3   108   104-CI-T01  Pre-PQ Process  SCMS-698  ASN-727  Côte d'Ivoire
# 4  1245   100-CI-T01  Pre-PQ Process    SCMS-1    ASN-5  Côte d'Ivoire
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              CIP           Air  ...
# 1   PMO - US  Direct Drop              CIP           Air  ...
# 2   PMO - US  Direct Drop              CIP           Air  ...
# 3   PMO - US  Direct Drop              CIP           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure _Per Pack_ Line Item Quantity Line Item Value Pack Price  \
# 0                         60                425        10837.50      25.50
# 1                         60                579        14764.50      25.50
# 2                         60               5721       145885.50      25.50
# 3                         60               5513       140581.50      25.50
# 4                         40                147        11076.45      75.35
#
#   Unit Price    Manufacturing Site First Line Designation  \
# 0       0.42    BMS Meymac, France                   True
# 1       0.42    BMS Meymac, France                   True
# 2       0.42    BMS Meymac, France                   True
# 3       0.42    BMS Meymac, France                   True
# 4       1.88  Bio-Rad Laboratories                   True
#
#            Weight _Kilograms_                  Freight Cost _USD_  \
# 0  Weight Captured Separately  Freight Included in Commodity Cost
# 1  Weight Captured Separately  Freight Included in Commodity Cost
# 2                        1232  Freight Included in Commodity Cost
# 3                        2126  Freight Included in Commodity Cost
# 4                         165                             1816.57
#
#   Line Item Insurance _USD_
# 0                       NaN
# 1                       NaN
# 2                    233.42
# 3                    224.93
# 4                       NaN
#
# [5 rows x 33 columns]

# %%
df = df.dropna()

df = df.copy()
df.head()
# Out:
#      ID Project Code            PQ #   PO _ SO #  ASN_DN #        Country  \
# 2  6671   104-CI-T01  Pre-PQ Process    SCMS-609   ASN-704  Côte d'Ivoire
# 3   108   104-CI-T01  Pre-PQ Process    SCMS-698   ASN-727  Côte d'Ivoire
# 5  4302   104-CI-T01  Pre-PQ Process  SCMS-18280  ASN-1550  Côte d'Ivoire
# 6   391   104-CI-T01  Pre-PQ Process  SCMS-18290  ASN-1879  Côte d'Ivoire
# 7  5661   104-CI-T01  Pre-PQ Process  SCMS-19100  ASN-1598  Côte d'Ivoire
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 2   PMO - US  Direct Drop              CIP           Air  ...
# 3   PMO - US  Direct Drop              CIP           Air  ...
# 5   PMO - US  Direct Drop              EXW           Air  ...
# 6   PMO - US  Direct Drop              EXW           Air  ...
# 7   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure _Per Pack_ Line Item Quantity Line Item Value Pack Price  \
# 2                         60               5721        145885.5       25.5
# 3                         60               5513        140581.5       25.5
# 5                         40                476         36176.0       76.0
# 6                         40                476         36176.0       76.0
# 7                         40                331         25156.0       76.0
#
#   Unit Price    Manufacturing Site First Line Designation Weight _Kilograms_  \
# 2       0.42    BMS Meymac, France                   True               1232
# 3       0.42    BMS Meymac, France                   True               2126
# 5       1.90  Bio-Rad Laboratories                   True                522
# 6       1.90  Bio-Rad Laboratories                   True                509
# 7       1.90  Bio-Rad Laboratories                   True                366
#
#                    Freight Cost _USD_ Line Item Insurance _USD_
# 2  Freight Included in Commodity Cost                    233.42
# 3  Freight Included in Commodity Cost                    224.93
# 5                             6924.83                     57.88
# 6                             5446.51                     57.88
# 7                             7915.98                     40.25
#
# [5 rows x 33 columns]

# %%
df['delay_days'] = (
    pd.to_datetime(df['Delivered to Client Date']) -
    pd.to_datetime(df['Scheduled Delivery Date'])
).dt.days

df[['delay_days']].head()
# Out:
#    delay_days
# 2           0
# 3           0
# 5           3
# 6           0
# 7           0
